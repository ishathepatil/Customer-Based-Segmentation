# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import dabl

# %%
data = pd.read_csv("Mall_Customers.csv")

# %%
data.shape
# Out:
# (200, 5)

# %% [markdown]
# 200 rows and 5 columns

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.sample(3)
# Out:
#      CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 173         174   Male   36                  87                      92
# 81           82   Male   38                  54                      55
# 131         132   Male   39                  71                      75

# %%
sns.pairplot(data)
plt.show()

# %%
sns.heatmap(data.corr(), annot = True, cmap = 'copper')
plt.title("Heatmap of the data", fontsize = 15)
plt.show()

# %%
dabl.plot(data, target_col = "Spending Score (1-100)")
# Out:
# Target looks like regression
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# [array([[<AxesSubplot:title={'center':'F=2.37E+01'}, xlabel='Age', ylabel='Spending Score (1...'>,
#          <AxesSubplot:title={'center':'F=1.94E-02'}, xlabel='Annual Income (k$)'>]],
#        dtype=object),
#  array([[<AxesSubplot:title={'center':'F=6.45E-02'}, xlabel='Spending Score (1...', ylabel='Gender'>]],
#        dtype=object)]

# %%
dabl.plot(data, target_col = "Annual Income (k$)")
# Out:
# Target looks like regression
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# [array([[<AxesSubplot:title={'center':'F=3.04E-02'}, xlabel='Age', ylabel='Annual Income (k$)'>,
#          <AxesSubplot:title={'center':'F=1.94E-02'}, xlabel='Spending Score (1...'>]],
#        dtype=object),
#  array([[<AxesSubplot:title={'center':'F=0.00E+00'}, xlabel='Annual Income (k$)', ylabel='Gender'>]],
#        dtype=object)]

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.describe(include = 'object')
# Out:
#         Gender
# count      200
# unique       2
# top     Female
# freq       112

# %%
#finding null values in the dataset
data.isnull().any()
# Out:
# CustomerID                False
# Gender                    False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %% [markdown]
# no null values

# %% [markdown]
# ## Data Visualization

# %%
plt.rcParams['figure.figsize'] = (18,8) 


plt.subplot(1,2,1)
sns.set(style = "whitegrid")
sns.distplot(data['Annual Income (k$)'])
plt.title("Distribution of annual income", fontsize = 20)
plt.xlabel('Range of Anual income')
plt.ylabel('Count')

plt.subplot(1,2,2)
sns.set(style = "whitegrid")
sns.distplot(data['Age'], color = 'red')
plt.title("Distribution age", fontsize = 20)
plt.xlabel('Range of age')
plt.ylabel('Count')
# Out:
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
labels = ['Female','Male']
size = data['Gender'].value_counts()
colors = ['lightgreen','orange']
explode = [0,0.001]

plt.rcParams['figure.figsize'] = (9,9)
plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, startangle  = 90,
        autopct = '%.2f%%')
plt.title('Gender Gap', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15,8)
sns.countplot(data['Age'], palette = 'hsv')
plt.title("Distribution of age", fontsize = 20)
plt.show()
# Out:
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.rcParams['figure.figsize'] = (20,8)
sns.distplot(data['Annual Income (k$)'], color = 'red')
plt.title("Distribution of annual income", fontsize = 20)
plt.show()
# Out:
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.rcParams['figure.figsize'] = (20,8)
sns.distplot(data['Spending Score (1-100)'], color = 'green')
plt.title("Distribution of Spending Score", fontsize = 20)
plt.show()
# Out:
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.rcParams['figure.figsize'] = (18,7)
sns.boxenplot(data['Gender'], data['Spending Score (1-100)'], palette = 'Blues')
plt.title('Gender Vs Spending Score', fontsize = 20)
plt.show()
# Out:
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.rcParams['figure.figsize'] = (18,7)
sns.violinplot(data['Gender'], data['Annual Income (k$)'], palette = 'rainbow')
plt.title("Gender Vs Annual Income", fontsize = 20)
plt.show()
# Out:
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.rcParams['figure.figsize'] = (18,7)
sns.stripplot(data['Gender'], data['Age'], palette = 'Purples', size =10)
plt.title('Gender vs Age', fontsize = 20)
plt.show()
# Out:
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x = data['Annual Income (k$)']
y = data['Age']
z = data['Spending Score (1-100)']

sns.lineplot(x,y, color = 'blue')
sns.lineplot(x,z, color = 'pink')
plt.title("Annual Income vs Age and Spending Score", fontsize = 20)
plt.show()
# Out:
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Isha Patil\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
